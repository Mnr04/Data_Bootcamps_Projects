# %% [markdown]
# # Exploring eBay Car Sales Data
#
# This project involves exploring and analyzing a dataset of used cars from eBay Kleinanzeigen, a classifieds section of the German eBay website. The dataset, originally scraped and modified to resemble real-world, uncleaned data, includes information on car listings such as price, model, registration year, odometer readings, and more.
#
# The goal of this project is to clean the dataset and perform initial analyses, using pandas for data manipulation. This project also highlights some of the advantages of working in a Jupyter environment.

# %%
import pandas as pd
import numpy as np

autos = pd.read_csv("Dataset/autos.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[10], line 4
#       1 import pandas as pd
#       2 import numpy as np
# ----> 4 autos = pd.read_csv("Dataset/autos.csv")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xdc in position 732: invalid continuation byte

# %% [markdown]
# We noticed some errors when we tried to open the file with UTF-8 encoding.

# %%
autos = pd.read_csv("Dataset/autos.csv", encoding="latin1")

# %%
autos.info()

# %%
autos.head()

# %% [markdown]
# ### Dataset Overview
#
# The dataset contains **371,528** rows and **20 columns**, which represent various attributes of used car . Here are some key observations:
#
# - **Data Completeness**:
#   - Most columns are fully populated, but some contain missing values, notably:
#     - `vehicleType` (333,659 non-null values)
#     - `gearbox` (351,319 non-null values)
#     - `model` (351,044 non-null values)
#     - `fuelType` (338,142 non-null values)
#     - `notRepairedDamage` (299,468 non-null values)
#
# - **Data Types**:
#   - The dataset includes a mix of numerical (`int64`) and categorical (`object`) data.
#   - Key numerical fields include `price`, `powerPS`, `yearOfRegistration`, `kilometer`, and `postalCode`.
#   - Categorical data includes fields like `name`, `seller`, `offerType`, `vehicleType`, and `fuelType`.

# %% [markdown]
# ### Cleaning Column Names

# %% [markdown]
# **The column names use camelcase instead of Python's preferred snakecase**

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
new_columns_name = (['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
       'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
       'kilometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
       'last_seen'])

# %%
autos.columns = new_columns_name

# %%
autos.head()
# Out:
#           date_crawled                            name  seller offer_type  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat    Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat    Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat    Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat    Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat    Angebot
#
#    price abtest vehicle_type  registration_year    gearbox  power_ps  model  \
# 0    480   test          NaN               1993    manuell         0   golf
# 1  18300   test        coupe               2011    manuell       190    NaN
# 2   9800   test          suv               2004  automatik       163  grand
# 3   1500   test   kleinwagen               2001    manuell        75   golf
# 4   3600   test   kleinwagen               2008    manuell        69  fabia
#
#    kilometer  registration_month fuel_type       brand unrepaired_damage  \
# 0     150000                   0    benzin  volkswagen               NaN
# 1     125000                   5    diesel        audi                ja
# 2     125000                   8    diesel        jeep               NaN
# 3     150000                   6    benzin  volkswagen              nein
# 4      90000                   7    diesel       skoda              nein
#
#             ad_created  nr_of_pictures  postal_code            last_seen
# 0  2016-03-24 00:00:00               0        70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00               0        66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00               0        90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00               0        91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00               0        60437  2016-04-06 10:17:21

# %% [markdown]
# **Changing column names to snake_case improves readability and consistency, making data processing and analysis easier with tools like Pandas. This convention helps avoid case-related errors and makes the code more maintainable.**

# %% [markdown]
# ###  Initial Exploration and Cleaning

# %% [markdown]
# For Price

# %%
autos.head()

# %%
autos.info()

# %%
autos["price"].shape

# %%
autos["price"].describe

# %%
autos = autos.loc[autos["price"] != 0]

# %% [markdown]
# **Entries with a price of 0 were removed as they often represent data entry errors or missing values, which could skew the analysis and statistics by introducing non-representative values of the used car market.**

# %%
autos['price'].value_counts().sort_index(ascending=True)
# Out:
# price
# 1             1189
# 2               12
# 3                8
# 4                1
# 5               26
#               ...
# 32545461         1
# 74185296         1
# 99000000         1
# 99999999        15
# 2147483647       1
# Name: count, Length: 5596, dtype: int64

# %%
autos = autos[autos['price'] >= 1000]

# %%
autos['price'].value_counts().sort_index(ascending=True)
# Out:
# price
# 1000          4649
# 1001            11
# 1003             1
# 1009             1
# 1010             2
#               ...
# 32545461         1
# 74185296         1
# 99000000         1
# 99999999        15
# 2147483647       1
# Name: count, Length: 5095, dtype: int64

# %%
autos = autos[autos['price'] <= 27000000]

# %%
autos['price'].value_counts().sort_index(ascending=True)
# Out:
# price
# 1000        4649
# 1001          11
# 1003           1
# 1009           1
# 1010           2
#             ...
# 10000000       8
# 10010011       1
# 11111111      10
# 12345678       9
# 14000500       1
# Name: count, Length: 5089, dtype: int64

# %% [markdown]
# I decided to remove all cars priced below 1000 and all cars listed at 27 million, as this price represents the most expensive car in the world.

# %% [markdown]
# For Km :

# %%
autos['kilometer'].value_counts().sort_index(ascending=True)
# Out:
# kilometer
# 5000        3634
# 10000       1723
# 20000       5027
# 30000       5640
# 40000       6184
# 50000       7343
# 60000       8257
# 70000       9193
# 80000      10195
# 90000      11294
# 100000     13693
# 125000     31976
# 150000    174014
# Name: count, dtype: int64

# %%
autos["price"].describe
# Out:
# <bound method NDFrame.describe of 1         18300
# 2          9800
# 3          1500
# 4          3600
# 6          2200
#           ...
# 371523     2200
# 371524     1199
# 371525     9200
# 371526     3400
# 371527    28990
# Name: price, Length: 288173, dtype: int64>

# %% [markdown]
# For the price, the data seems accurate.

# %% [markdown]
# ### Exploring the Date Columns

# %% [markdown]
# Three columns (date_crawled, last_seen, ad_created) are stored as strings and need to be converted to a numerical or datetime format for analysis. The other two (registration_month, registration_year) are already numeric and can be analyzed directly.

# %%
autos["date_crawled"].head
# Out:
# <bound method NDFrame.head of 1         2016-03-24 10:58:45
# 2         2016-03-14 12:52:21
# 3         2016-03-17 16:54:04
# 4         2016-03-31 17:25:20
# 6         2016-04-01 20:48:51
#                  ...
# 371523    2016-03-14 17:48:27
# 371524    2016-03-05 19:56:21
# 371525    2016-03-19 18:57:12
# 371526    2016-03-20 19:41:08
# 371527    2016-03-07 19:39:19
# Name: date_crawled, Length: 288173, dtype: object>

# %%
# Convert columns to datetime
autos['date_crawled'] = pd.to_datetime(autos['date_crawled'])
autos['ad_created'] = pd.to_datetime(autos['ad_created'])
autos['last_seen'] = pd.to_datetime(autos['last_seen'])

# %%
# Extract only the date part (remove the time)
autos['date_crawled'] = autos['date_crawled'].dt.date
autos['ad_created'] = autos['ad_created'].dt.date
autos['last_seen'] = autos['last_seen'].dt.date

# %%
# Calculate the distribution as percentages and sort by date for each column
date_crawled_dist = autos['date_crawled'].value_counts(normalize=True, dropna=False).sort_index()
ad_created_dist = autos['ad_created'].value_counts(normalize=True, dropna=False).sort_index()
last_seen_dist = autos['last_seen'].value_counts(normalize=True, dropna=False).sort_index()

# %%
# Print the results
print("Distribution of date_crawled:")
print(date_crawled_dist)

print("\nDistribution of ad_created:")
print(ad_created_dist)

print("\nDistribution of last_seen:")
print(last_seen_dist)
# Out:
# Distribution of date_crawled:
# date_crawled
# 2016-03-05    0.025835
# 2016-03-06    0.014679
# 2016-03-07    0.035208
# 2016-03-08    0.032973
# 2016-03-09    0.033469
# 2016-03-10    0.032539
# 2016-03-11    0.032762
# 2016-03-12    0.036617
# 2016-03-13    0.016077
# 2016-03-14    0.036374
# 2016-03-15    0.032505
# 2016-03-16    0.029694
# 2016-03-17    0.030995
# 2016-03-18    0.012944
# 2016-03-19    0.035489
# 2016-03-20    0.036641
# 2016-03-21    0.035132
# 2016-03-22    0.032036
# 2016-03-23    0.031793
# 2016-03-24    0.029847
# 2016-03-25    0.032939
# 2016-03-26    0.032748
# 2016-03-27    0.030856
# 2016-03-28    0.035291
# 2016-03-29    0.033858
# 2016-03-30    0.033164
# 2016-03-31    0.031516
# 2016-04-01    0.034705
# 2016-04-02    0.035982
# 2016-04-03    0.039761
# 2016-04-04    0.037970
# 2016-04-05    0.012763
# 2016-04-06    0.003210
# 2016-04-07    0.001627
# Name: proportion, dtype: float64
#
# Distribution of ad_created:
# ad_created
# 2014-03-10    0.000003
# 2015-03-20    0.000003
# 2015-06-11    0.000003
# 2015-06-18    0.000003
# 2015-08-07    0.000003
#                 ...
# 2016-04-03    0.040007
# 2016-04-04    0.038050
# 2016-04-05    0.011507
# 2016-04-06    0.003210
# 2016-04-07    0.001555
# Name: proportion, Length: 112, dtype: float64
#
# Distribution of last_seen:
# last_seen
# 2016-03-05    0.001110
# 2016-03-06    0.003651
# 2016-03-07    0.004653
# 2016-03-08    0.007312
# 2016-03-09    0.008804
# 2016-03-10    0.010452
# 2016-03-11    0.012152
# 2016-03-12    0.021751
# 2016-03-13    0.007804
# 2016-03-14    0.011656
# 2016-03-15    0.015033
# 2016-03-16    0.015439
# 2016-03-17    0.027098
# 2016-03-18    0.006579
# 2016-03-19    0.015435
# 2016-03-20    0.018763
# 2016-03-21    0.018943
# 2016-03-22    0.019544
# 2016-03-23    0.017083
# 2016-03-24    0.018270
# 2016-03-25    0.017965
# 2016-03-26    0.015106
# 2016-03-27    0.015796
# 2016-03-28    0.021123
# 2016-03-29    0.022285
# 2016-03-30    0.022407
# 2016-03-31    0.022990
# 2016-04-01    0.023295
# 2016-04-02    0.024312
# 2016-04-03    0.024579
# 2016-04-04    0.024329
# 2016-04-05    0.133461
# 2016-04-06    0.232149
# 2016-04-07    0.138670
# Name: proportion, dtype: float64

# %%
autos.head(0)
# Out:
# Empty DataFrame
# Columns: [date_crawled, name, seller, offer_type, price, abtest, vehicle_type, registration_year, gearbox, power_ps, model, kilometer, registration_month, fuel_type, brand, unrepaired_damage, ad_created, nr_of_pictures, postal_code, last_seen]
# Index: []

# %%
autos["registration_year"].describe()
# Out:
# count    288173.000000
# mean       2005.147699
# std          65.534244
# min        1000.000000
# 25%        2001.000000
# 50%        2005.000000
# 75%        2009.000000
# max        9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# From our previous exploration, we observed anomalies in the registration_year column: the minimum value is 1000, predating the invention of cars, and the maximum value is 9999, extending far into the future. Given that cars cannot be registered after the listing date, any registration year beyond 2016 is definitely inaccurate. Determining the earliest valid year is more complex but likely falls within the early 1900s. We will count the number of listings with registration years outside the 1900-2016 range to decide whether to remove these rows or apply more nuanced logic.

# %%
autos['registration_year'].value_counts().sort_index(ascending=True)
# Out:
# registration_year
# 1000    10
# 1001     1
# 1039     1
# 1111     1
# 1234     1
#         ..
# 7800     1
# 8500     1
# 8888     2
# 9000     3
# 9999     7
# Name: count, Length: 128, dtype: int64

# %%
autos = autos[autos['registration_year'] >= 1900]
autos = autos[autos['registration_year'] <=  2016]

# %%
autos['registration_year'].value_counts().sort_index(ascending=True)
# Out:
# registration_year
# 1910      14
# 1911       1
# 1923       3
# 1925       1
# 1927       2
#         ...
# 2012    9319
# 2013    6067
# 2014    4691
# 2015    2704
# 2016    4868
# Name: count, Length: 94, dtype: int64

# %%
autos[autos['registration_year'] < 1950]
# Out:
#        date_crawled                                               name  \
# 2018     2016-03-25                            Volkswagen_Andere_typ82
# 2376     2016-03-15                                      Andere_Andere
# 10549    2016-03-17         Ford_V8_Cabrio_im_restaurierten_Topzustand
# 10691    2016-03-27  Tausche/Verkaufe_S51_gegen_Audi_ab_150ps_oder_...
# 12468    2016-03-22               Opel_Olympia_Cabrio_1936_Top_Zustand
# ...             ...                                                ...
# 352061   2016-03-15                     Oldtimer_Aero_30_Roadster_1938
# 352421   2016-03-11                                  BMW_DIXI_OLDTIMER
# 354533   2016-03-05            Ford_Business_Coupe_Hotrod_Projekt.1937
# 362834   2016-03-26  Oldtimer_Unikat_Volkswagen_Anfibio_Schwimmwage...
# 370654   2016-03-16               Mercedes_Benz_170V___Vorkriegsmodell
#
#         seller offer_type  price   abtest vehicle_type  registration_year  \
# 2018    privat    Angebot   7000     test          suv               1945
# 2376    privat    Angebot   1800  control       cabrio               1925
# 10549   privat    Angebot  35000  control       cabrio               1937
# 10691   privat    Angebot   1250     test          NaN               1910
# 12468   privat    Angebot  21900  control       cabrio               1936
# ...        ...        ...    ...      ...          ...                ...
# 352061  privat    Angebot  17000     test       cabrio               1944
# 352421  privat    Angebot  20000  control        coupe               1929
# 354533  privat    Angebot   7000     test        coupe               1937
# 362834  privat    Angebot  18900  control          suv               1943
# 370654  privat    Angebot   6000  control    limousine               1937
#
#         gearbox  power_ps   model  kilometer  registration_month fuel_type  \
# 2018    manuell        48  andere     150000                   2    benzin
# 2376        NaN         0     NaN       5000                   1       NaN
# 10549   manuell        90  andere       5000                   6    benzin
# 10691       NaN         0  andere       5000                   0       NaN
# 12468   manuell        23  andere       5000                   7    benzin
# ...         ...       ...     ...        ...                 ...       ...
# 352061  manuell        30     NaN       5000                   1    benzin
# 352421  manuell        12  andere      10000                   4    benzin
# 354533  manuell        85  andere       5000                   8    benzin
# 362834  manuell        60  andere     150000                   3    benzin
# 370654  manuell        38  andere       5000                   0    benzin
#
#                  brand unrepaired_damage  ad_created  nr_of_pictures  \
# 2018        volkswagen              nein  2016-03-25               0
# 2376    sonstige_autos              nein  2016-03-15               0
# 10549             ford              nein  2016-03-17               0
# 10691             audi               NaN  2016-03-27               0
# 12468             opel              nein  2016-03-22               0
# ...                ...               ...         ...             ...
# 352061  sonstige_autos              nein  2016-03-15               0
# 352421             bmw               NaN  2016-03-11               0
# 354533            ford                ja  2016-03-05               0
# 362834      volkswagen              nein  2016-03-26               0
# 370654   mercedes_benz               NaN  2016-03-16               0
#
#         postal_code   last_seen
# 2018          58135  2016-03-25
# 2376          79288  2016-04-07
# 10549         50859  2016-04-07
# 10691         18445  2016-04-07
# 12468         78467  2016-04-05
# ...             ...         ...
# 352061        45897  2016-03-26
# 352421        74523  2016-04-07
# 354533         8359  2016-04-07
# 362834        51065  2016-03-26
# 370654        23936  2016-03-30
#
# [119 rows x 20 columns]

# %%
autos = autos[autos['registration_year'] >= 1950]

# %%
autos.value_counts(normalize=True)
# Out:
# date_crawled  name                                                     seller  offer_type  price  abtest   vehicle_type  registration_year  gearbox    power_ps  model     kilometer  registration_month  fuel_type  brand       unrepaired_damage  ad_created  nr_of_pictures  postal_code  last_seen
# 2016-03-22    XC_90_D5_SPORT_DYNAUDIO_7_SITZE_1.HAND_S_HEFT            privat  Angebot     10000  control  suv           2008               automatik  185       xc_reihe  90000      1                   diesel     volvo       nein               2016-03-22  0               10115        2016-03-22    0.000014
#               Touareg_3.0_V6_TDI_DPF_Aut._Bi_Xen_1_Hand_Kamera         privat  Angebot     10100  control  suv           2008               automatik  239       touareg   100000     12                  diesel     volkswagen  nein               2016-03-22  0               10115        2016-03-22    0.000014
# 2016-03-11    A3_2.0_TDI_Sportback_S_tronic_2X_S_LINE_PANORAMA         privat  Angebot     9500   test     limousine     2012               automatik  170       a3        80000      6                   diesel     audi        nein               2016-03-11  0               10115        2016-03-11    0.000014
#               A5_3.0_TDI_DPF_quattro_S_tronic_NAVI_XEN_2xS_LINE        privat  Angebot     10500  test     limousine     2011               automatik  239       a5        125000     9                   diesel     audi        nein               2016-03-11  0               10115        2016-03-11    0.000014
#               Tiguan_2.0_TDI_4Motion_DSG_Sport&Style                   privat  Angebot     10000  test     suv           2011               automatik  140       tiguan    100000     8                   diesel     volkswagen  nein               2016-03-11  0               10115        2016-03-11    0.000014
#                                                                                                                                                                                                                                                                                                              ...
# 2016-03-16    Bastlerfahrzeug                                          privat  Angebot     1000   test     kombi         2004               automatik  0         mondeo    150000     4                   diesel     ford        ja                 2016-03-16  0               33659        2016-03-17    0.000005
#               Bastlerfahrzeug_Ford_Mondeo_gegen_Gebot_zu_verkaufen.    privat  Angebot     1000   control  kombi         2005               manuell    131       mondeo    150000     12                  diesel     ford        ja                 2016-03-16  0               24941        2016-03-16    0.000005
#               Biete_BMW_316_E36                                        privat  Angebot     2000   control  coupe         1997               manuell    102       3er       150000     6                   benzin     bmw         nein               2016-03-16  0               25524        2016-04-01    0.000005
#               Biete_Chevrolet_Matiz_rechte_seite_leichte_unfallschade  privat  Angebot     1150   control  kleinwagen    2008               manuell    0         matiz     90000      6                   benzin     chevrolet   ja                 2016-03-16  0               42697        2016-03-16    0.000005
# 2016-04-07    zetec_maschine_mit_H&R_fahrwerk                          privat  Angebot     1299   control  kleinwagen    1999               manuell    131       focus     150000     6                   benzin     ford        nein               2016-04-07  0               56235        2016-04-07    0.000005
# Name: proportion, Length: 218890, dtype: float64

# %%
autos['registration_year'].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# registration_year
# 1950    0.000058
# 1951    0.000061
# 1952    0.000040
# 1953    0.000061
# 1954    0.000050
#           ...
# 2012    0.033611
# 2013    0.021882
# 2014    0.016919
# 2015    0.009753
# 2016    0.017558
# Name: proportion, Length: 67, dtype: float64

# %% [markdown]
# The distribution of registration_year shows that earlier years, such as 1950 and 1951, have very low proportions, indicating that cars from those years are quite rare in the dataset. The proportion increases steadily up to 2016, with a notable peak around 2012. This suggests that more recent years are better represented in the dataset. Specifically, years like 2012 and 2013 have higher proportions compared to earlier years, indicating that there are more listings for newer cars. The proportions for years closer to 2016, like 2014 and 2015, show a decrease, which might suggest a drop in listings for very recent cars or could reflect a possible data collection bias.

# %% [markdown]
# ### Exploring Price by Brand

# %%
autos["brand"].unique()
# Out:
# array(['audi', 'jeep', 'volkswagen', 'skoda', 'peugeot', 'ford', 'mazda',
#        'nissan', 'renault', 'mercedes_benz', 'bmw', 'honda', 'opel',
#        'mini', 'smart', 'hyundai', 'subaru', 'volvo', 'mitsubishi',
#        'alfa_romeo', 'kia', 'seat', 'suzuki', 'lancia', 'porsche',
#        'citroen', 'fiat', 'toyota', 'chevrolet', 'sonstige_autos',
#        'dacia', 'daihatsu', 'chrysler', 'jaguar', 'rover', 'saab',
#        'daewoo', 'land_rover', 'trabant', 'lada'], dtype=object)

# %%
brand_analyse = autos["brand"].value_counts()

# %%
brand_analyse
# Out:
# brand
# volkswagen        58804
# bmw               34651
# mercedes_benz     30875
# audi              27888
# opel              24261
# ford              16019
# renault           10291
# peugeot            7990
# fiat               5808
# skoda              5097
# seat               4938
# smart              4571
# toyota             4104
# mazda              4031
# citroen            3782
# nissan             3342
# mini               3224
# hyundai            2994
# sonstige_autos     2759
# volvo              2426
# porsche            2120
# kia                2081
# honda              1986
# mitsubishi         1839
# suzuki             1714
# alfa_romeo         1694
# chevrolet          1629
# chrysler           1024
# dacia               847
# land_rover          746
# jeep                738
# jaguar              581
# subaru              484
# saab                391
# daihatsu            385
# trabant             267
# lancia              254
# daewoo              243
# rover               209
# lada                173
# Name: count, dtype: int64

# %% [markdown]
# I have decided to choose Volkswagen for the analysis because it has the largest amount of data, which will provide more weight to the results.

# %%
brands = {}

# %%
volkswagen_brands = autos[autos["brand"] == "volkswagen"]

# %%
volkswagen_brands
# Out:
#        date_crawled                                               name  \
# 3        2016-03-17                                 GOLF_4_1_4__3TÜRER
# 11       2016-04-07      Volkswagen_Passat_Variant_2.0_TDI_Comfortline
# 13       2016-03-21                     VW_PASSAT_1.9_TDI_131_PS_LEDER
# 20       2016-04-01                  Volkswagen_Scirocco_1.4_TSI_Sport
# 28       2016-03-09                               Volkswagen_T3_andere
# ...             ...                                                ...
# 371509   2016-03-11  LT_35_DIESEL_Gruene_Plakette....letzte_Gelegen...
# 371516   2016-04-04                                Volkswagen_Lupo_1.0
# 371517   2016-03-28                   Volkswagen_Golf_2.0_TDI_DPF_Team
# 371525   2016-03-19                 Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526   2016-03-20                             VW_Golf_Kombi_1_9l_TDI
#
#         seller offer_type  price   abtest vehicle_type  registration_year  \
# 3       privat    Angebot   1500     test   kleinwagen               2001
# 11      privat    Angebot   2799  control        kombi               2005
# 13      privat    Angebot   2500  control        kombi               2004
# 20      privat    Angebot  10400  control        coupe               2009
# 28      privat    Angebot   1990     test          bus               1981
# ...        ...        ...    ...      ...          ...                ...
# 371509  privat    Angebot   1900     test          NaN               2000
# 371516  privat    Angebot   1490  control   kleinwagen               1998
# 371517  privat    Angebot   7900     test    limousine               2010
# 371525  privat    Angebot   9200     test          bus               1996
# 371526  privat    Angebot   3400     test        kombi               2002
#
#         gearbox  power_ps        model  kilometer  registration_month  \
# 3       manuell        75         golf     150000                   6
# 11      manuell       140       passat     150000                  12
# 13      manuell       131       passat     150000                   2
# 20      manuell       160     scirocco     100000                   4
# 28      manuell        50  transporter       5000                   1
# ...         ...       ...          ...        ...                 ...
# 371509  manuell       110          NaN     150000                   7
# 371516  manuell        50         lupo     150000                   9
# 371517  manuell       140         golf     150000                   7
# 371525  manuell       102  transporter     150000                   3
# 371526  manuell       100         golf     150000                   6
#
#        fuel_type       brand unrepaired_damage  ad_created  nr_of_pictures  \
# 3         benzin  volkswagen              nein  2016-03-17               0
# 11        diesel  volkswagen                ja  2016-04-07               0
# 13           NaN  volkswagen              nein  2016-03-21               0
# 20        benzin  volkswagen              nein  2016-04-01               0
# 28        benzin  volkswagen              nein  2016-03-09               0
# ...          ...         ...               ...         ...             ...
# 371509       NaN  volkswagen              nein  2016-03-11               0
# 371516    benzin  volkswagen              nein  2016-04-04               0
# 371517    diesel  volkswagen              nein  2016-03-28               0
# 371525    diesel  volkswagen              nein  2016-03-19               0
# 371526    diesel  volkswagen               NaN  2016-03-20               0
#
#         postal_code   last_seen
# 3             91074  2016-03-17
# 11            57290  2016-04-07
# 13            90762  2016-03-23
# 20            75365  2016-04-05
# 28            87471  2016-03-10
# ...             ...         ...
# 371509        87700  2016-03-12
# 371516        48653  2016-04-06
# 371517        75223  2016-04-02
# 371525        87439  2016-04-07
# 371526        40764  2016-03-24
#
# [58804 rows x 20 columns]

# %%
volkswagen_mean_price = volkswagen_brands["price"].mean()
brands = {"volkswagen" : volkswagen_mean_price }

# %%
print(brands)
# Out:
# {'volkswagen': 8761.34550370723}

# %% [markdown]
# We can see that the mean price for volkswagen cars is 8761.34

# %%
I create a function to automatise this workflow

# %%
brands_dict = {}

def update_brand_mean_price(dataframe, brand_name, brands_dict):
    # Filter the DataFrame by the brand name
    brand_data = dataframe[dataframe['brand'] == brand_name]
    
    # Calculate the mean price
    mean_price = brand_data['price'].mean()
    
    # Update the dictionary
    brands_dict[brand_name] = mean_price

# %%
for brand_name in brand_analyse.index:
    update_brand_mean_price(autos, brand_name, brands_dict)

# %%
brands_dict
# Out:
# {'volkswagen': 8761.34550370723,
#  'bmw': 9942.717843640876,
#  'mercedes_benz': 9742.940340080972,
#  'audi': 11333.108039300057,
#  'opel': 4814.637896212028,
#  'ford': 6806.517135901117,
#  'renault': 3559.205908075017,
#  'peugeot': 4088.5470588235294,
#  'fiat': 6255.520661157025,
#  'skoda': 6927.274475181479,
#  'seat': 5767.324827865533,
#  'smart': 3887.7481951432947,
#  'toyota': 5769.293372319688,
#  'mazda': 7685.189034978914,
#  'citroen': 4608.209677419355,
#  'nissan': 6402.149311789348,
#  'mini': 10168.12034739454,
#  'hyundai': 6331.589846359386,
#  'sonstige_autos': 33420.569771656395,
#  'volvo': 6658.387469084913,
#  'porsche': 53087.16084905661,
#  'kia': 6648.516098029793,
#  'honda': 5069.84944612286,
#  'mitsubishi': 4969.922240348015,
#  'suzuki': 5621.380980163361,
#  'alfa_romeo': 5369.078512396694,
#  'chevrolet': 8098.6967464702275,
#  'chrysler': 5171.435546875,
#  'dacia': 6033.410861865407,
#  'land_rover': 17180.533512064343,
#  'jeep': 12797.822493224932,
#  'jaguar': 15023.905335628227,
#  'subaru': 6364.237603305785,
#  'saab': 4947.028132992327,
#  'daihatsu': 2948.2181818181816,
#  'trabant': 44682.50187265917,
#  'lancia': 5402.216535433071,
#  'daewoo': 1537.6666666666667,
#  'rover': 2748.0382775119615,
#  'lada': 3691.057803468208}

# %%
sorted_brands_dict = dict(sorted(brands_dict.items(), key=lambda item: item[1], reverse=True))

# %%
sorted_brands_dict
# Out:
# {'porsche': 53087.16084905661,
#  'trabant': 44682.50187265917,
#  'sonstige_autos': 33420.569771656395,
#  'land_rover': 17180.533512064343,
#  'jaguar': 15023.905335628227,
#  'jeep': 12797.822493224932,
#  'audi': 11333.108039300057,
#  'mini': 10168.12034739454,
#  'bmw': 9942.717843640876,
#  'mercedes_benz': 9742.940340080972,
#  'volkswagen': 8761.34550370723,
#  'chevrolet': 8098.6967464702275,
#  'mazda': 7685.189034978914,
#  'skoda': 6927.274475181479,
#  'ford': 6806.517135901117,
#  'volvo': 6658.387469084913,
#  'kia': 6648.516098029793,
#  'nissan': 6402.149311789348,
#  'subaru': 6364.237603305785,
#  'hyundai': 6331.589846359386,
#  'fiat': 6255.520661157025,
#  'dacia': 6033.410861865407,
#  'toyota': 5769.293372319688,
#  'seat': 5767.324827865533,
#  'suzuki': 5621.380980163361,
#  'lancia': 5402.216535433071,
#  'alfa_romeo': 5369.078512396694,
#  'chrysler': 5171.435546875,
#  'honda': 5069.84944612286,
#  'mitsubishi': 4969.922240348015,
#  'saab': 4947.028132992327,
#  'opel': 4814.637896212028,
#  'citroen': 4608.209677419355,
#  'peugeot': 4088.5470588235294,
#  'smart': 3887.7481951432947,
#  'lada': 3691.057803468208,
#  'renault': 3559.205908075017,
#  'daihatsu': 2948.2181818181816,
#  'rover': 2748.0382775119615,
#  'daewoo': 1537.6666666666667}

# %% [markdown]
# ### Storing Aggregate Data in a DataFrame

# %% [markdown]
# We aim to find a link between brands, price, and mileage.

# %%
mileage_dict = {}

def update_brand_mean_mileage(dataframe, brand_name, mileage_dict):
  
    brand_data = dataframe[dataframe['brand'] == brand_name]

    mean_mileage = brand_data['kilometer'].mean()
    
    mileage_dict[brand_name] = mean_mileage

for brand_name in brand_analyse.index:
    update_brand_mean_mileage(autos, brand_name, mileage_dict)

# %%
sorted_mileage_dict = dict(sorted(mileage_dict.items(), key=lambda item: item[1], reverse=True))

# %%
sorted_mileage_dict
# Out:
# {'saab': 139808.18414322252,
#  'volvo': 136065.53998351196,
#  'bmw': 132183.77536001848,
#  'chrysler': 131855.46875,
#  'mercedes_benz': 129777.81376518219,
#  'rover': 128803.82775119618,
#  'audi': 128045.75444635686,
#  'alfa_romeo': 125796.93034238489,
#  'volkswagen': 125510.08434800354,
#  'opel': 123066.85627138206,
#  'jaguar': 122865.7487091222,
#  'subaru': 121580.57851239669,
#  'jeep': 121124.66124661246,
#  'mazda': 120983.62689159017,
#  'honda': 120944.1087613293,
#  'renault': 120898.35778835876,
#  'peugeot': 119752.19023779724,
#  'mitsubishi': 119676.45459488852,
#  'land_rover': 119296.24664879356,
#  'ford': 119290.52999563019,
#  'daewoo': 117530.86419753087,
#  'citroen': 115708.61977789529,
#  'toyota': 115063.35282651072,
#  'lancia': 114901.5748031496,
#  'seat': 114721.54718509519,
#  'skoda': 112429.86070237395,
#  'nissan': 111710.0538599641,
#  'fiat': 107434.57300275483,
#  'daihatsu': 106909.09090909091,
#  'kia': 105055.26189332052,
#  'suzuki': 101423.57059509918,
#  'hyundai': 99604.20841683367,
#  'porsche': 99476.41509433962,
#  'chevrolet': 99014.73296500921,
#  'smart': 97216.14526361847,
#  'mini': 93694.16873449131,
#  'sonstige_autos': 88907.21275824575,
#  'dacia': 85519.48051948052,
#  'lada': 69739.88439306358,
#  'trabant': 52546.816479400746}

# %% [markdown]
# Convert both dictionaries to series objects

# %%
mean_price_series = pd.Series(brands_dict)
mileage_mean_series = pd.Series(mileage_dict)

# %%
df = pd.DataFrame(mean_price_series, columns=['mean_price'])

# %%
df
# Out:
#                   mean_price
# volkswagen       8761.345504
# bmw              9942.717844
# mercedes_benz    9742.940340
# audi            11333.108039
# opel             4814.637896
# ford             6806.517136
# renault          3559.205908
# peugeot          4088.547059
# fiat             6255.520661
# skoda            6927.274475
# seat             5767.324828
# smart            3887.748195
# toyota           5769.293372
# mazda            7685.189035
# citroen          4608.209677
# nissan           6402.149312
# mini            10168.120347
# hyundai          6331.589846
# sonstige_autos  33420.569772
# volvo            6658.387469
# porsche         53087.160849
# kia              6648.516098
# honda            5069.849446
# mitsubishi       4969.922240
# suzuki           5621.380980
# alfa_romeo       5369.078512
# chevrolet        8098.696746
# chrysler         5171.435547
# dacia            6033.410862
# land_rover      17180.533512
# jeep            12797.822493
# jaguar          15023.905336
# subaru           6364.237603
# saab             4947.028133
# daihatsu         2948.218182
# trabant         44682.501873
# lancia           5402.216535
# daewoo           1537.666667
# rover            2748.038278
# lada             3691.057803

# %%
df["mean_mileage"] = mileage_mean_series

# %%
df
# Out:
#                   mean_price   mean_mileage
# volkswagen       8761.345504  125510.084348
# bmw              9942.717844  132183.775360
# mercedes_benz    9742.940340  129777.813765
# audi            11333.108039  128045.754446
# opel             4814.637896  123066.856271
# ford             6806.517136  119290.529996
# renault          3559.205908  120898.357788
# peugeot          4088.547059  119752.190238
# fiat             6255.520661  107434.573003
# skoda            6927.274475  112429.860702
# seat             5767.324828  114721.547185
# smart            3887.748195   97216.145264
# toyota           5769.293372  115063.352827
# mazda            7685.189035  120983.626892
# citroen          4608.209677  115708.619778
# nissan           6402.149312  111710.053860
# mini            10168.120347   93694.168734
# hyundai          6331.589846   99604.208417
# sonstige_autos  33420.569772   88907.212758
# volvo            6658.387469  136065.539984
# porsche         53087.160849   99476.415094
# kia              6648.516098  105055.261893
# honda            5069.849446  120944.108761
# mitsubishi       4969.922240  119676.454595
# suzuki           5621.380980  101423.570595
# alfa_romeo       5369.078512  125796.930342
# chevrolet        8098.696746   99014.732965
# chrysler         5171.435547  131855.468750
# dacia            6033.410862   85519.480519
# land_rover      17180.533512  119296.246649
# jeep            12797.822493  121124.661247
# jaguar          15023.905336  122865.748709
# subaru           6364.237603  121580.578512
# saab             4947.028133  139808.184143
# daihatsu         2948.218182  106909.090909
# trabant         44682.501873   52546.816479
# lancia           5402.216535  114901.574803
# daewoo           1537.666667  117530.864198
# rover            2748.038278  128803.827751
# lada             3691.057803   69739.884393

# %% [markdown]
# The aggregated data reveals significant variations in average prices and mileage across car brands. Luxury brands such as Porsche, Jaguar, and Land Rover have the highest average prices, with Porsche leading at €53,087, followed by Jaguar and Land Rover at €15,024 and €17,181, respectively. Conversely, budget brands like Dacia, Daewoo, and Trabant show the lowest average prices, with Dacia at €6,033, Daewoo at €1,538, and Trabant at €44,683, which might reflect atypical data or specific segmentation.
#
# Mileage also varies notably, with brands like Saab and Peugeot having the highest average mileage, while luxury brands like Porsche have lower mileage. This suggests that luxury vehicles may be better maintained or less used compared to budget models. German brands such as Audi, BMW, and Mercedes-Benz, while having relatively high prices, have average mileages close to the overall average, indicating a balance between cost and wear. Overall, the analysis highlights significant trends in pricing and mileage across different car brands, reflecting variations based on price category and market segment.
